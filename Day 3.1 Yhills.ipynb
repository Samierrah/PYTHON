# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)  #adds a nice background to the graphs
#tells python to actually display the graphs

# %%
### load and review the dataset
auto=pd.read_csv('https://raw.githubusercontent.com/Samierrah/yhills-dated-April2nd/main/auto-mpg.csv')

# %%
auto.shape
# Out:
# (398, 9)

# %%
auto.head(10)
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin                   car name
# 0  18.0    8  307.0  130  3504  12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165  3693  11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150  3436  11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150  3433  12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140  3449  10.5  70       1                ford torino
# 5  15.0    8  429.0  198  4341  10.0  70       1           ford galaxie 500
# 6  14.0    8  454.0  220  4354   9.0  70       1           chevrolet impala
# 7  14.0    8  440.0  215  4312   8.5  70       1          plymouth fury iii
# 8  14.0    8  455.0  225  4425  10.0  70       1           pontiac catalina
# 9  15.0    8  390.0  190  3850   8.5  70       1         amc ambassador dpl

# %%
auto.tail(10)
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin                    car name
# 388  26.0    4  156.0   92  2585  14.5  82       1  chrysler lebaron medallion
# 389  22.0    6  232.0  112  2835  14.7  82       1              ford granada l
# 390  32.0    4  144.0   96  2665  13.9  82       3            toyota celica gt
# 391  36.0    4  135.0   84  2370  13.0  82       1           dodge charger 2.2
# 392  27.0    4  151.0   90  2950  17.3  82       1            chevrolet camaro
# 393  27.0    4  140.0   86  2790  15.6  82       1             ford mustang gl
# 394  44.0    4   97.0   52  2130  24.6  82       2                   vw pickup
# 395  32.0    4  135.0   84  2295  11.6  82       1               dodge rampage
# 396  28.0    4  120.0   79  2625  18.6  82       1                 ford ranger
# 397  31.0    4  119.0   82  2720  19.4  82       1                  chevy s-10

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mpg       398 non-null    float64
#  1   cyl       398 non-null    int64
#  2   disp      398 non-null    float64
#  3   hp        398 non-null    object
#  4   wt        398 non-null    int64
#  5   acc       398 non-null    float64
#  6   yr        398 non-null    int64
#  7   origin    398 non-null    int64
#  8   car name  398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
auto.dtypes
# Out:
# mpg         float64
# cyl           int64
# disp        float64
# hp           object
# wt            int64
# acc         float64
# yr            int64
# origin        int64
# car name     object
# dtype: object

# %%
sns.distplot(auto['acc'],color='green')
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='acc', ylabel='Density'>

# %%
sns.jointplot(auto['hp'],auto['wt'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
sns.jointplot(auto['cyl'],auto['disp'], kind="hex")
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(auto['cyl'],auto['disp'], kind="kde")
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(auto)

# %%
sns.stripplot(auto['disp'], auto['hp'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='disp', ylabel='hp'>

# %%
sns.swarmplot(auto['yr'], auto['origin'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 77.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.boxplot(auto['yr'], auto['origin'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr', ylabel='origin'>

# %%
sns.boxplot(auto['yr'], auto['origin'], hue=auto['cyl'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr', ylabel='origin'>

# %%
sns.countplot(x='yr',data=auto)
# Out:
# <AxesSubplot:xlabel='yr', ylabel='count'>

# %%
sns.barplot(auto['yr'], auto['origin'], hue=auto['cyl'])
# Out:
# C:\Users\samie\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yr', ylabel='origin'>
